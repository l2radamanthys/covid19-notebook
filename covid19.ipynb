# %%
import pandas as pd

# %%
df = pd.read_csv('owid-covid-data.csv')
df.head()
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# 2           0                  112.395                 74.930
# 3           0                  159.227                 46.831
# 4           0                  177.959                 18.733
#
#    total_deaths_per_million  new_deaths_per_million  total_tests  new_tests  \
# 0                       0.0                     0.0          NaN        NaN
# ...

# %%
df.describe()
# Out:
#          total_cases     new_cases  total_deaths    new_deaths  \
# count   11833.000000  11833.000000  11833.000000  11833.000000
# mean     3330.670836    192.767515    187.944731     13.479591
# std     23723.207365   1426.015070   1489.032223    111.743742
# min         0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000      0.000000
# 50%        16.000000      1.000000      0.000000      0.000000
# 75%       262.000000     21.000000      4.000000      0.000000
# max    735086.000000  35527.000000  38910.000000   4928.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             11642.000000           11642.000000
# mean                210.771975              11.750346
# std                 829.717868              69.832878
# min                   0.000000               0.000000
# 25%                   0.000000               0.000000
# 50%                   2.611000               0.038000
# ...
